# %%
import xlsxwriter
from datetime import datetime
workbook = xlsxwriter.Workbook('QueryOutput.xlsx')
worksheet = workbook.add_worksheet()
expenses = []
with open("Q8") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            newLine = []
            for i in range(0,len(splitLine)):
                print(splitLine[i])
                #if i != 1:
                if i != 1:
                    newLine.append(splitLine[i].replace('\n', ' ').replace('\r', ''))
                else:
                    newLine.append(splitLine[i].split()[1])
            expenses.append(tuple(newLine))
            
# Some data we want to write to the worksheet.
#expenses = (
#    ['Rent', 1000],
#    ['Gas',   100],
#    ['Food',  300],
#    ['Gym',    50],
#)

# Start from the first cell. Rows and columns are zero indexed.
row = 0
col = 0

format5 = workbook.add_format({'num_format': 'hh:mm:ss.SS'})

# Iterate over the data and write it out row by row.
for runID, time, endToEndDelay, opGCreation, nodeDiscovery, plAD, selPath, overallCost, energy, bdp in (expenses):
    worksheet.write(row, col,     int(runID))
    worksheet.write(row, col + 1, datetime.strptime(time, '%H:%M:%S.%f'),format5)
    worksheet.write(row, col + 2, int(endToEndDelay))
    worksheet.write(row, col + 3, int(opGCreation))
    worksheet.write(row, col + 4, int(nodeDiscovery))
    worksheet.write(row, col + 5, int(plAD))
    worksheet.write(row, col + 6, selPath)
    worksheet.write(row, col + 7, float(overallCost))
    worksheet.write(row, col + 8, float(energy))
    worksheet.write(row, col + 9, float(bdp))
    row += 1


workbook.close()
# Out:
# 3
# 2019-02-07 22:08:38.154
# 7273
# 3
# 3343
# 3880
# 9007-9003-9002-9001
# 10.690000000000001
# 100.0
# 0.23
#
# 4
# 2019-02-07 22:09:18.199
# 7011
# 15
# 3566
# 3417
# 9007-9003-9002-9001
# 0.62
# 100.0
# 0.21
#
# 6
# 2019-02-07 22:10:38.290
# 8108
# 1
# 3852
# 4242
# 9006-9005-9002-9001
# 0.59
# 99.67
# 0.2
#
# 7
# 2019-02-07 22:11:18.338
# 7790
# 4
# 3601
# 4178
# 9006-9005-9002-9001
# 0.48000000000000004
# 98.67
# 0.16
#
# 8
# 2019-02-07 22:11:58.455
# 4406
# 2
# 87
# 4301
# 9006-9005-9002-9001
# 0.48000000000000004
# 98.67
# 0.16
#
# 9
# 2019-02-07 22:12:38.443
# 7734
# 1
# 3760
# 3957
# 9007-9003-9002-9001
# 0.8400000000000001
# 98.67
# 0.28
#
# 10
# 2019-02-07 22:13:18.497
# 7763
# 1
# 3992
# 3764
# 9007-9003-9002-9001
# 40.010000000000005
# 98.67
# 0.19
#
# 11
# 2019-02-07 22:13:58.532
# 3846
# 5
# 78
# 3754
# 9007-9003-9002-9001
# 40.010000000000005
# 98.67
# 0.19
#
# 12
# 2019-02-07 22:14:38.572
# 8549
# 1
# 4080
# 4460
# 9006-9005-9002-9001
# 0.66
# 98.67
# 0.22
#
# 13
# ...

# %%
import xlsxwriter
from datetime import datetime
workbook = xlsxwriter.Workbook('queryWeightVariance.xlsx')
worksheet = workbook.add_worksheet()
expenses = []
with open("queryWeightVariance") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            newLine = []
            for i in range(0,len(splitLine)):
                if i != 1:
                    newLine.append(splitLine[i].replace('\n', ' ').replace('\r', ''))
                else:
                    newLine.append(splitLine[i].split()[1])
            expenses.append(tuple(newLine))
            
# Some data we want to write to the worksheet.
#expenses = (
#    ['Rent', 1000],
#    ['Gas',   100],
#    ['Food',  300],
#    ['Gym',    50],
#)

# Start from the first cell. Rows and columns are zero indexed.
row = 0
col = 0

format5 = workbook.add_format({'num_format': 'hh:mm:ss.SS'})

# Iterate over the data and write it out row by row.
for runID, time, endToEndDelay, opGCreation, EnergyWeight, OverheadWeight in (expenses):
    worksheet.write(row, col,     int(runID))
    worksheet.write(row, col + 1, datetime.strptime(time, '%H:%M:%S.%f'),format5)
    worksheet.write(row, col + 2, int(endToEndDelay))
    worksheet.write(row, col + 3, opGCreation)
    worksheet.write(row, col + 4, EnergyWeight)
    worksheet.write(row, col + 5, OverheadWeight)
    row += 1


workbook.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8bb0a94c9ef0> in <module>()
# ----> 1 import xlsxwriter
#       2 from datetime import datetime
#       3 workbook = xlsxwriter.Workbook('queryWeightVariance.xlsx')
#       4 worksheet = workbook.add_worksheet()
#       5 expenses = []
#
# ImportError: No module named xlsxwriter

# %%
import pandas as pd
import seaborn as sns

Results = {'Name':[], 'Value':[]}
val1 = []
val2 = []
val3 = []
val4 = []
val5 = []
val6 = []
val7 = []
val8 = []
with open("Q1") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q1")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
   
with open("Q2") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q2")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
with open("Q3") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q3")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
with open("Q4") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q4")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
with open("Q5") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q5")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
with open("Q6") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q6")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
        
with open("Q7") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q7")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
with open("Q8") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q8")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
#Results['Name'].append("Q1")
#Results['Value'].append(val1)
#Results['Name'].append("Q2")
#Results['Value'].append(val2)
#Results['Name'].append("Q3")
#Results['Value'].append(val3)
#Results['Name'].append("Q4")
#Results['Value'].append(val4)
#Results['Name'].append("Q5")
#Results['Value'].append(val5)
#Results['Name'].append("Q6")
#Results['Value'].append(val6)
#Results['Name'].append("Q7")
#Results['Value'].append(val7)
#Results['Name'].append("Q8")
#Results['Value'].append(val8)
df = pd.DataFrame(Results)
#options(tibble.print_max = 1e9)
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(df)
#tips = sns.load_dataset("tips")
#print(tips)
sns.set(style="whitegrid")
ax = sns.boxplot(x="Name", y="Value", data = df, palette=["C0", "C1", "C3", "C4", "C5", "C6", "C7", "C8"])
ax.set(xlabel='Query', ylabel ='Total Delay in ms')
#print(df)
# Out:
# [Text(0, 0.5, 'Total Delay in ms'), Text(0.5, 0, 'Query')]

# %%
import pandas as pd
import seaborn as sns

Results = {'Name':[], 'Value':[], 'System':[]}
val1 = []
val2 = []
val3 = []
val4 = []
val5 = []
val6 = []
val7 = []
val8 = []
with open("Q1_old") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q1")
            Results['System'].append("old")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
   
with open("Q1") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q1")
            Results['System'].append("new")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
with open("Q2_old") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q2")
            Results['System'].append("old")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            
with open("Q2") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q2")
            Results['System'].append("new")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
with open("Q3_old") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q3")
            Results['System'].append("old")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
        
with open("Q3") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q3")
            Results['System'].append("new")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
            
#Results['Name'].append("Q1")
#Results['Value'].append(val1)
#Results['Name'].append("Q2")
#Results['Value'].append(val2)
#Results['Name'].append("Q3")
#Results['Value'].append(val3)
#Results['Name'].append("Q4")
#Results['Value'].append(val4)
#Results['Name'].append("Q5")
#Results['Value'].append(val5)
#Results['Name'].append("Q6")
#Results['Value'].append(val6)
#Results['Name'].append("Q7")
#Results['Value'].append(val7)
#Results['Name'].append("Q8")
#Results['Value'].append(val8)
df = pd.DataFrame(Results)
#options(tibble.print_max = 1e9)
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(df)
#tips = sns.load_dataset("tips")
#print(tips)
sns.set(style="whitegrid")
ax = sns.boxplot(x="Name", y="Value", hue= "System", data = df)
ax.set(xlabel='Query', ylabel ='Total Delay in ms')
#print(df)
# Out:
# [Text(0, 0.5, 'Total Delay in ms'), Text(0.5, 0, 'Query')]

# %%
import pandas as pd
import seaborn as sns

Results = {'Tuples':[], 'Value':[], 'Algorithm':[]}
with open("ComplexityAnalysis/Prediction1Pure") as f:
    for line in f:
        splitLine=line.split(",")
        Results['Tuples'].append(int(splitLine[1]))
        Results['Value'].append(float(splitLine[2].replace('\n', ' ')))
        Results['Algorithm'].append("Prediction 1")
    
with open("ComplexityAnalysis/Prediction2Pure") as f:
    for line in f:
        splitLine=line.split(",")
        Results['Tuples'].append(int(splitLine[1]))
        Results['Value'].append(float(splitLine[2].replace('\n', ' ')))
        Results['Algorithm'].append("Prediction 2")
    
df = pd.DataFrame(Results)
df.head(240)
sns.set(style="whitegrid")

ax = sns.lineplot(x="Tuples", y="Value", hue="Algorithm", ci=95, data=df)
ax.set(ylabel ='Time in ms')
# Out:
# [Text(0, 0.5, 'Time in ms')]

# %%
# Out:
#   File "<ipython-input-4-6db47854e351>", line 1
#     conda install -c anaconda seaborn=0.9.0
#                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import seaborn as sns

Results = {'Tuples':[], 'Value':[], 'Algorithm':[],'N':[]}
with open("ComplexityAnalysis/Prediction1N") as f:
    for line in f:
        splitLine=line.split(",")
        Results['Tuples'].append(int(splitLine[1]))
        Results['N'].append(int(splitLine[2]))
        Results['Value'].append(float(splitLine[3].replace('\n', ' ')))
        Results['Algorithm'].append("Prediction 1")
    
with open("ComplexityAnalysis/Prediction2N") as f:
    for line in f:
        splitLine=line.split(",")
        Results['Tuples'].append(int(splitLine[1]))
        Results['N'].append(int(splitLine[2]))
        Results['Value'].append(float(splitLine[3].replace('\n', ' ')))
        Results['Algorithm'].append("Prediction 2")
    
df = pd.DataFrame(Results)
df.head(240)
sns.set(style="whitegrid")

ax = sns.lineplot(x="N", y="Value", hue="Algorithm",data=df)
ax.set(xlabel='Number of individual plugs', ylabel ='Time in ms')
# Out:
# [Text(0, 0.5, 'Time in ms'), Text(0.5, 0, 'Number of individual plugs')]

# %%
import pandas as pd
import seaborn as sns

Results = {'PackageSize':[], 'Value':[],'Algorthm':[], 'Measurement':[],'MeasureMentAlgo':[]}
#1kb
Results['PackageSize'].append(1)
Results['Value'].append(1)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Precision Prediction 1")

Results['PackageSize'].append(1)
Results['Value'].append(1)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Recall Prediction 1")

Results['PackageSize'].append(1)
Results['Value'].append(1)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Accuracy Prediction 1")

Results['PackageSize'].append(1)
Results['Value'].append(1)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("F-Measure Prediction 1")

#2kb
Results['PackageSize'].append(2)
Results['Value'].append(1)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Precision Prediction 1")

Results['PackageSize'].append(2)
Results['Value'].append(1)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Recall Prediction 1")

Results['PackageSize'].append(2)
Results['Value'].append(1)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Accuracy Prediction 1")

Results['PackageSize'].append(2)
Results['Value'].append(1)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("F-Measure Prediction 1")

#3kb
Results['PackageSize'].append(3)
Results['Value'].append(1)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Precision Prediction 1")

Results['PackageSize'].append(3)
Results['Value'].append(0.66)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Recall Prediction 1")

Results['PackageSize'].append(3)
Results['Value'].append(0.66)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Accuracy Prediction 1")

Results['PackageSize'].append(3)
Results['Value'].append(0.75)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("F-Measure Prediction 1")

#4kb
Results['PackageSize'].append(4)
Results['Value'].append(1)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Precision Prediction 1")

Results['PackageSize'].append(4)
Results['Value'].append(0.5)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Recall Prediction 1")

Results['PackageSize'].append(4)
Results['Value'].append(0.5)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Accuracy Prediction 1")

Results['PackageSize'].append(4)
Results['Value'].append(0.66)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("F-Measure Prediction 1")

#5kb
Results['PackageSize'].append(5)
Results['Value'].append(0)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Precision Prediction 1")

Results['PackageSize'].append(5)
Results['Value'].append(0)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Recall Prediction 1")

Results['PackageSize'].append(5)
Results['Value'].append(0)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("Accuracy Prediction 1")

Results['PackageSize'].append(5)
Results['Value'].append(0)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 1")
Results['MeasureMentAlgo'].append("F-Measure Prediction 1")

#Prediction2
#1kb
Results['PackageSize'].append(1)
Results['Value'].append(1)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Precision Prediction 2")

Results['PackageSize'].append(1)
Results['Value'].append(1)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Recall Prediction 2")

Results['PackageSize'].append(1)
Results['Value'].append(1)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Accuracy Prediction 2")

Results['PackageSize'].append(1)
Results['Value'].append(1)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("F-Measure Prediction 2")

#2kb
Results['PackageSize'].append(2)
Results['Value'].append(1)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Precision Prediction 2")

Results['PackageSize'].append(2)
Results['Value'].append(1)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Recall Prediction 2")

Results['PackageSize'].append(2)
Results['Value'].append(1)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Accuracy Prediction 2")

Results['PackageSize'].append(2)
Results['Value'].append(1)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("F-Measure Prediction 2")

#3kb
Results['PackageSize'].append(3)
Results['Value'].append(1)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Precision Prediction 2")

Results['PackageSize'].append(3)
Results['Value'].append(1)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Recall Prediction 2")

Results['PackageSize'].append(3)
Results['Value'].append(1)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Accuracy Prediction 2")

Results['PackageSize'].append(3)
Results['Value'].append(1)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("F-Measure Prediction 2")

#4kb
Results['PackageSize'].append(4)
Results['Value'].append(1)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Precision Prediction 2")

Results['PackageSize'].append(4)
Results['Value'].append(1)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Recall Prediction 2")

Results['PackageSize'].append(4)
Results['Value'].append(1)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Accuracy Prediction 2")

Results['PackageSize'].append(4)
Results['Value'].append(1)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("F-Measure Prediction 2")

#5kb
Results['PackageSize'].append(5)
Results['Value'].append(0)
Results['Measurement'].append("Precision")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Precision Prediction 2")

Results['PackageSize'].append(5)
Results['Value'].append(0)
Results['Measurement'].append("Recall")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Recall Prediction 2")

Results['PackageSize'].append(5)
Results['Value'].append(0)
Results['Measurement'].append("Accuracy")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("Accuracy Prediction 2")

Results['PackageSize'].append(5)
Results['Value'].append(0)
Results['Measurement'].append("F-Measure")
Results['Algorthm'].append("Prediction 2")
Results['MeasureMentAlgo'].append("F-Measure Prediction 2")

df = pd.DataFrame(Results)
sns.set(style="whitegrid")

ax = sns.lineplot(x="PackageSize", y="Value", hue="MeasureMentAlgo",data=df)

# %%
import pandas as pd
import seaborn as sns

Results = {'Name':[], 'Value':[]}
val1 = []
val2 = []
val3 = []
val4 = []
val5 = []
val6 = []
val7 = []
val8 = []
   
with open("output_D") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("10")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
    
with open("output_B") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("20")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            
with open("output_C") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("30")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            


with open("output_A") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("40")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))

            
df = pd.DataFrame(Results)
#options(tibble.print_max = 1e9)
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(df)
#tips = sns.load_dataset("tips")
#print(tips)
sns.set(style="whitegrid")
ax = sns.boxplot(x="Name", y="Value", data = df)
ax.set(xlabel='Queries', ylabel ='End-to-end Delay in ms')
#print(df)
# Out:
# [Text(0,0.5,'End-to-end Delay in ms'), Text(0.5,0,'Queries')]

# %%
import pandas as pd
import seaborn as sns

Results = {'Name':[], 'Value':[]}
val1 = []
val2 = []
val3 = []
val4 = []
val5 = []
val6 = []
val7 = []
val8 = []
with open("run2/output_A") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q1")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
   
with open("run2/output_B") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q2")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            
with open("run2/output_C") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q3")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            
with open("run2/output_D") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q4")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            
df = pd.DataFrame(Results)
#options(tibble.print_max = 1e9)
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(df)
#tips = sns.load_dataset("tips")
#print(tips)
sns.set(style="whitegrid")
ax = sns.boxplot(x="Name", y="Value", data = df)
ax.set(xlabel='Query', ylabel ='Total Delay in ms')
#print(df)
# Out:
# [Text(0,0.5,'Total Delay in ms'), Text(0.5,0,'Query')]

# %%
import pandas as pd
import seaborn as sns
import numpy as np

Results = {'Name':[], 'Value':[], 'PathBDP': [], 'PathEnergy': []}
val1 = []
val2 = []
val3 = []
val4 = []
val5 = []
val6 = []
val7 = []
val8 = []
   
with open("run3/output_B") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("10")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
           
            
with open("run3/output_C") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("20")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
           
            
with open("run3/output_D") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("30")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
                       
with open("run3/output_A") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("40")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
            
with open("run3/output_G") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("50")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
            
df = pd.DataFrame(Results)
#options(tibble.print_max = 1e9)
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(df)
#tips = sns.load_dataset("tips")
#print(tips)
sns.set(style="whitegrid")
ax = sns.boxplot(x="Name", y="Value", data = df, palette=["C2"], showmeans=True)
ax.set(xlabel='Queries', ylabel ='Total Delay in ms')
m1 = df.groupby(['Name'])['Value'].median().values
print(m1)
mL1 = [str(np.round(s, 2)) for s in m1]

'''ind = 0
for tick in range(len(ax.get_xticklabels())):
    ax.text(tick-.2, m1[ind+1]+1, mL1[ind+1],  horizontalalignment='center',  color='w', weight='semibold')
    ax.text(tick+.2, m1[ind]+1, mL1[ind], horizontalalignment='center', color='w', weight='semibold')
    ind += 2 
#print(df)'''
# Out:
# [11057.   8953.5 14297.  14475.  15522.5]
# "ind = 0\nfor tick in range(len(ax.get_xticklabels())):\n    ax.text(tick-.2, m1[ind+1]+1, mL1[ind+1],  horizontalalignment='center',  color='w', weight='semibold')\n    ax.text(tick+.2, m1[ind]+1, mL1[ind], horizontalalignment='center', color='w', weight='semibold')\n    ind += 2 \n#print(df)"

# %%
import pandas as pd
import seaborn as sns

Results = {'Name':[], 'Value':[], 'PathBDP': [], 'PathEnergy': []}
val1 = []
val2 = []
val3 = []
val4 = []
val5 = []
val6 = []
val7 = []
val8 = []
   
with open("run8/output_B") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("10")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
            
with open("run8/output_C") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("20")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
            
with open("run8/output_D") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("30")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
            
            
with open("run8/output_G") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("40")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
            

with open("run8/output_A") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("50")
            Results['Value'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['PathEnergy'].append(float(splitLine[9].replace('\n', ' ').replace('\r', '')))
            Results['PathBDP'].append(float(splitLine[10].replace('\n', ' ').replace('\r', '')))
            
            
df = pd.DataFrame(Results)
#options(tibble.print_max = 1e9)
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(df)
#tips = sns.load_dataset("tips")
#print(tips)
sns.set(style="whitegrid", font_scale=5)
ax = sns.boxplot(x="Name", y="PathBDP", palette=["C3"], data = df)
ax.set(xlabel='Queries', ylabel ='Total Delay in ms')
#print(df)
# Out:
# [Text(0,0.5,'Total Delay in ms'), Text(0.5,0,'Queries')]

# %%
#import matplotlib.pyplot as plt
#import numpy as np
import pandas as pd
import seaborn as sns

Results = {'Nested Queries':[], 'Number': [], 'Time':[]}

with open("parser_filter.txt") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Nested Queries'].append("Query 2")
            Results['Time'].append(float(splitLine[1].replace('\n', ' ').replace('\r', '')))
            Results['Number'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            
with open("parser_join.txt") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Nested Queries'].append("Query 3")
            Results['Time'].append(float(splitLine[1].replace('\n', ' ').replace('\r', '')))
            Results['Number'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))

df=pd.DataFrame(Results)
sns.set(style="whitegrid")
ax = sns.lineplot(x="Number", y="Time", hue="Nested Queries", palette=["C1", "C2"], data=df)
ax.set(xlabel='Number of Nested Operators',  ylabel ='Time in ms')
# Out:
# [Text(0,0.5,'Time in ms'), Text(0.5,0,'Number of Nested Operators')]

# %%
import pandas as pd
import seaborn as sns

Results = {'Name':[], 'Value':[], 'GC': [], 'Place': [], 'Comm': []}
val1 = []
val2 = []
val3 = []
val4 = []
val5 = []
val6 = []
val7 = []
val8 = []
with open("run2/q1") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q1")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            Results['GC'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['Place'].append(float(splitLine[4].replace('\n', ' ').replace('\r', '')))
            Results['Comm'].append(float(splitLine[5].replace('\n', ' ').replace('\r', '')))
   
with open("run2/q2") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q2")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            Results['GC'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['Place'].append(float(splitLine[4].replace('\n', ' ').replace('\r', '')))
            Results['Comm'].append(float(splitLine[5].replace('\n', ' ').replace('\r', '')))
            
with open("run2/q3") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q3")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            Results['GC'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['Place'].append(float(splitLine[4].replace('\n', ' ').replace('\r', '')))
            Results['Comm'].append(float(splitLine[5].replace('\n', ' ').replace('\r', '')))
            
with open("run2/q4") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q4")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            Results['GC'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['Place'].append(float(splitLine[4].replace('\n', ' ').replace('\r', '')))
            Results['Comm'].append(float(splitLine[5].replace('\n', ' ').replace('\r', '')))
            
with open("run2/q5") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q5")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            Results['GC'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['Place'].append(float(splitLine[4].replace('\n', ' ').replace('\r', '')))
            Results['Comm'].append(float(splitLine[5].replace('\n', ' ').replace('\r', '')))
            
with open("run2/q6") as f:
    for line in f:
        if line.strip():
            splitLine=line.split(",")
            Results['Name'].append("Q6")
            Results['Value'].append(float(splitLine[2].replace('\n', ' ').replace('\r', '')))
            Results['GC'].append(float(splitLine[3].replace('\n', ' ').replace('\r', '')))
            Results['Place'].append(float(splitLine[4].replace('\n', ' ').replace('\r', '')))
            Results['Comm'].append(float(splitLine[5].replace('\n', ' ').replace('\r', '')))

#Results['Name'].append("Q1")
#Results['Value'].append(val1)
#Results['Name'].append("Q2")
#Results['Value'].append(val2)
#Results['Name'].append("Q3")
#Results['Value'].append(val3)
#Results['Name'].append("Q4")
#Results['Value'].append(val4)
#Results['Name'].append("Q5")
#Results['Value'].append(val5)
#Results['Name'].append("Q6")
#Results['Value'].append(val6)
#Results['Name'].append("Q7")
#Results['Value'].append(val7)
#Results['Name'].append("Q8")
#Results['Value'].append(val8)
df = pd.DataFrame(Results)

m0 = df.groupby(['Name'])['Value'].median().values
print(m0)

m1 = df.groupby(['Name'])['GC'].median().values
print(m1)

m2 = df.groupby(['Name'])['Place'].median().values
print(m2)

m3 = df.groupby(['Name'])['Comm'].median().values
print(m3)

#options(tibble.print_max = 1e9)
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #print(df)
#tips = sns.load_dataset("tips")
#print(tips)
sns.set(style="whitegrid", font_scale=1.5)
ax = sns.boxplot(x="Name", y="Comm", data = df, palette=["C0", "C1", "C2", "C3", "C4", "C5"])
ax.set(xlabel='Query', ylabel ='Communication Delay (ms)')
#print(df)
# Out:
# [ 132.   374.   851.5  979.5 1262.  1315. ]
# [0.  0.5 1.  0.  1.  0. ]
# [ 131.   372.   850.   978.5 1261.  1314. ]
# [131.  248.  263.5 364.  289.  463. ]
# [Text(0,0.5,'Communication Delay (ms)'), Text(0.5,0,'Query')]
