# %%
import sqlite3
conn = sqlite3.connect('smarter.db')
c = conn.cursor()
#query = "SELECT name FROM sqlite_master WHERE type='table';"
#c.execute(query)
c.execute('SELECT * FROM movements WHERE id = 1')
for i in c.fetchall():
    for j in i:
        print(str(j)+",",end='')
    print("")
# Out:
# 2017-09-02 10:16:18,1,51.81861114501953,8.727097511291504,158.1007537841797,32.0,None,None,
# 2017-09-02 10:16:19,1,51.81862258911133,8.727100372314453,158.30685424804688,12.0,1.288506756651875,1.288506756651875,
# 2017-09-02 10:16:19,1,51.81862258911133,8.727100372314453,157.68243408203125,12.0,0.0,None,
# 2017-09-02 10:16:20,1,51.81862258911133,8.727100372314453,158.53799438476562,12.0,0.0,0.0,
# 2017-09-02 10:16:21,1,51.81862258911133,8.727100372314453,157.32858276367188,12.0,0.0,0.0,
# 2017-09-02 10:16:22,1,51.81862258911133,8.727100372314453,156.62351989746094,12.0,0.0,0.0,
# 2017-09-02 10:16:23,1,51.81862258911133,8.727100372314453,155.72128295898438,8.0,0.0,0.0,
# 2017-09-02 10:16:24,1,51.81862258911133,8.727100372314453,155.14523315429688,8.0,0.0,0.0,
# 2017-09-02 10:16:25,1,51.81862258911133,8.727100372314453,154.15281677246094,8.0,0.0,0.0,
# 2017-09-02 10:16:26,1,51.81862258911133,8.727100372314453,154.04371643066406,8.0,0.0,0.0,
# ...
